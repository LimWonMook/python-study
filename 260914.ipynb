# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
# 파이썬 문법 시작

# %% [markdown]
# ## 파이썬 문법 시작

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
print('안녕하세요')
print('안녕하세요')
print('안녕하세요')
print('안녕하세요')
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %% [markdown]
# ## 데이터 타입

# %%
'Hello' # 문자열
# Out:
# 'Hello'

# %%
29 # 숫자(정수)
# Out:
# 29

# %%
3.14 # 숫자(실수)
# Out:
# 3.14

# %%
print('29')
# Out:
# 29

# %%
type('Hello')
# Out:
# str

# %%
type(29)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
True, False
# Out:
# (True, False)

# %%
type(True)
# Out:
# bool

# %% [markdown]
# ## 변수

# %%
myvar = 29

# %%
print(myvar)
print(myvar)
print(myvar)
print(myvar)
print(myvar)
# Out:
# 29
# 29
# 29
# 29
# 29

# %%
type(myvar)
# Out:
# int

# %% [markdown]
# ## 연산자

# %%
# 산술연산자
# +, -, *, /, //(몫), %(나머지), **(거듭제곱)

# %%
3 / 4
# Out:
# 0

# %%
num1 = 2
num2 = 10

# %%
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
print(num1 ** num2)
# Out:
# 12
# -8
# 20
# 0.2
# 0
# 2
# 1024

# %%
str1 = 'Hello'
str2 = 'World'

# %%
print(str1)
print(str2)
# Out:
# Hello
# World

# %%
str1 = 'Hello'
str2 = 3

# %%
print(str1 * str2)
# Out:
# HelloHelloHello

# %%
num1 = 2
num2 = 10

# %%
result = num1 + num2
result
# Out:
# 12

# %% [markdown]
# ## 비교연산자

# %% [markdown]
# 같니, 다르니, 크니, 작니
# ==, !=, >, <, >=, <=

# %%
5 == 3
# Out:
# False

# %%
5 > 4
# Out:
# True

# %%
mynumber = 100

# %%
result = mynumber >= 200
result
# Out:
# False

# %% [markdown]
# ## 사용자 입력

# %%
print('안녕하세요')
# Out:
# 안녕하세요

# %%
name = input("내 이름: ") # 사용자 입력함수
name
# Out:
# '임원묵'

# %%
print('내 이름은', name, '입니다.')
# Out:
# 내 이름은 임원묵 입니다.

# %%
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
print(num1 ** num2)
# Out:
# 12
# -8
# 20
# 0.2
# 0
# 2
# 1024

# %% [markdown]
# ## 미션 - 사용자에서 이름과 나이를 입력받아서 출력해주세요
# ## 출력예시: "내 이름은 박지만이고, 나이는 29 살 입니다."

# %%
name = input("내 이름: ") 
year = input("내 나이: ")

print('내 이름은', name, '이고, 나이는', year, '살 입니다.')
# Out:
# 내 이름은 임원묵 이고, 나이는 26  입니다.
