# %% [markdown]
# ## 가상환경

# %% [markdown]
# 터미널
# py --list
# py -3.13 --version
# py -3.13 -m venv .venv
#
# 가상환경
# .ven\Scripts\activate 복사
#
# deactivate
#
# pip list
# pip install ipykernel
#
# powershall X
# command prompt 누르고 다시 실행
#
# python -m pip ~~

# %%
# 가상환경
print('Hello')
# Out:
# Hello

# %% [markdown]
# ## 클래스

# %%
class Student:
    population = 0 # 클래스 변수 (공유)

    def __init__(self, name, age): # 생성자
        self.name = name # 인스턴스 변수
        self.age = age
        Student.population += 1

    # 매서드
    def hello(self):
        print(f'{self.name}님 안녕하세요.')

# %%
# 상속
class NewStudent(Student):
    population = 0 # 클래스 변수 (공유)

    # 새로운 메서드
    def study(self):
        print(f'{self.name}님 공부하세요.')

    # 메서드 오버라이딩
    def hello(self):
        print(f'{self.name}님 신~나게 안녕하세요.')

# %%
std3 = NewStudent('정윤교', 25)

# %%
std3.study
# Out:
# <bound method NewStudent.study of <__main__.NewStudent object at 0x000001D6C737BE00>>

# %%
std1 = Student('임원묵', 26)

# %%
std1.population
# Out:
# 1

# %%
std2 = Student('최동건', 25)

# %%
std1.population
# Out:
# 2

# %%
std2.hello() # name님 안녕하세요
# Out:
# 최동건님 안녕하세요.

# %%
std1 = Student()
std2 = Student()

std1.name = '임원묵'
std1.age = 26
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 std1 = Student()
#       2 std2 = Student()
#       3
#       4 std1.name = '임원묵'
#
# NameError: name 'Student' is not defined
